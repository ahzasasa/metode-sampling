# %% [markdown]
# ## Hipotesis
#
# H0: $\rho = 0$ (Tidak ada korelasi yang signifikan.) <br>
# H1: $\rho \neq 0$ (Ada korelasi yang signifikan.)

# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df = pd.read_csv("")

# %% [markdown]
# # Uji validitas

# %% [markdown]
# ## Nilai kritis

# %% [markdown]
# ## Statistik uji

# %% [markdown]
# ## Keputusan
